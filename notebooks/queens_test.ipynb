# %%
# %%time
import GetOldTweets3 as got
import datetime
import pandas as pd
import urllib.request as urllib2
from urllib.error import HTTPError
import time
import pickle
import retrying

full=pd.read_csv("county_centers.csv")
center=pd.DataFrame()
center['counties']=full['County [2]']
center['long']=full['Longitude']
center['lat']=full['Latitude']
start_date = datetime.date(2019, 12, 31)

end_date = datetime.date(2020, 6, 1)

delta = datetime.timedelta(days=1)
i=0
for ind in center.index:
    
    if center.counties[ind]=="Queens [10]":
        i=ind
        #print(i)

df_tweets=pd.DataFrame(columns={"Queens"})
tweet_dict = {}
def retry_got2(tweetCriteria):
    try:   
        tweets = got.manager.TweetManager.getTweets(tweetCriteria)
        return tweets
    
   
    except:
            print("go to sleep")
            time.sleep(300)
            retry_got(tweetCriteria)
            
while start_date <= end_date:
    start_date += delta
    df_tweets=df_tweets.append(pd.Series(name=start_date))
    #print(df_tweets)
   # e+=1
    #df_tweets=df_tweets.appenndd(pd.DataFrame(index=[str(start_date)]))
    
    location=str(center.lat[i])+", "+str(center.long[i])
    location = location.replace("°", "")
    location = location.replace("+", "")
    location=location.replace("\u2013", "-") #en dash
    #print(location)
    print(str(start_date))
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('*')\
                                           .setNear(location)\
                                           .setUntil(str(start_date))\
                                           .setMaxTweets(1000)\
                                           .setWithin("40km")
                                                                      
    #print(center.counties[i])
    tweets=retry_got(tweetCriteria)
    
    #try:   
        #tweets = got.manager.TweetManager.getTweets(tweetCriteria)
   
    #except:
            #print("go to sleep")
            #time.sleep(60)
            #tweets=retry_got(tweetCriteria)

       # if err.code == 429:
          #  print("hehehe gotcha")
      #  else:
           # print("hmm....")
            
   # try:
#tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    #    print(tweets.date)

        
       
    #except:
   #     print('no tweet in this county')
        
    for tweet in tweets:
    
        #print(tweet.text)
    #df_tweets['Queens'][start_date].append(tweet.text)
        tweet_dict.setdefault(start_date, []).append(tweet)
pickle.dump( tweet_dict, open( "save_queens.p", "wb" ) )

@retrying.retry(wait_fixed=10000)       
def retry_got(tweetCriteria):
    print("trying")
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    return tweets
# Out:
# /home/niklas/anaconda3/envs/bd4pp/lib/python3.7/site-packages/ipykernel_launcher.py:42: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# 2020-01-01
# trying
# 2020-01-02
# trying
# 2020-01-03
# trying
# 2020-01-04
# trying
# 2020-01-05
# trying
# 2020-01-06
# trying
# 2020-01-07
# trying
# 2020-01-08
# trying
# 2020-01-09
# trying
# 2020-01-10
# trying
# 2020-01-11
# trying
# 2020-01-12
# trying
# 2020-01-13
# trying
# 2020-01-14
# trying
# 2020-01-15
# trying
# 2020-01-16
# trying
# 2020-01-17
# trying
# 2020-01-18
# trying
# 2020-01-19
# trying
# 2020-01-20
# trying
# 2020-01-21
# trying
# 2020-01-22
# trying
# 2020-01-23
# trying
# 2020-01-24
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-01-24&src=typd
# trying
# 2020-01-25
# trying
# 2020-01-26
# trying
# 2020-01-27
# trying
# 2020-01-28
# trying
# 2020-01-29
# trying
# 2020-01-30
# trying
# 2020-01-31
# trying
# 2020-02-01
# trying
# 2020-02-02
# trying
# 2020-02-03
# trying
# 2020-02-04
# trying
# 2020-02-05
# trying
# 2020-02-06
# trying
# 2020-02-07
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-02-07&src=typd
# trying
# 2020-02-08
# trying
# 2020-02-09
# trying
# 2020-02-10
# trying
# 2020-02-11
# trying
# 2020-02-12
# trying
# 2020-02-13
# trying
# 2020-02-14
# trying
# 2020-02-15
# trying
# 2020-02-16
# trying
# 2020-02-17
# trying
# 2020-02-18
# trying
# 2020-02-19
# trying
# 2020-02-20
# trying
# 2020-02-21
# trying
# 2020-02-22
# trying
# 2020-02-23
# trying
# 2020-02-24
# trying
# 2020-02-25
# trying
# 2020-02-26
# trying
# 2020-02-27
# trying
# 2020-02-28
# trying
# 2020-02-29
# trying
# 2020-03-01
# trying
# 2020-03-02
# trying
# 2020-03-03
# trying
# 2020-03-04
# trying
# 2020-03-05
# trying
# 2020-03-06
# trying
# 2020-03-07
# trying
# 2020-03-08
# trying
# 2020-03-09
# trying
# 2020-03-10
# trying
# 2020-03-11
# trying
# 2020-03-12
# trying
# 2020-03-13
# trying
# 2020-03-14
# trying
# 2020-03-15
# trying
# 2020-03-16
# trying
# 2020-03-17
# trying
# 2020-03-18
# trying
# 2020-03-19
# trying
# 2020-03-20
# trying
# 2020-03-21
# trying
# 2020-03-22
# trying
# 2020-03-23
# trying
# 2020-03-24
# trying
# 2020-03-25
# trying
# 2020-03-26
# trying
# 2020-03-27
# trying
# 2020-03-28
# trying
# 2020-03-29
# trying
# 2020-03-30
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-03-30&src=typd
# trying
# 2020-03-31
# trying
# 2020-04-01
# trying
# 2020-04-02
# trying
# 2020-04-03
# trying
# 2020-04-04
# trying
# 2020-04-05
# trying
# 2020-04-06
# trying
# 2020-04-07
# trying
# 2020-04-08
# trying
# 2020-04-09
# trying
# 2020-04-10
# trying
# 2020-04-11
# trying
# 2020-04-12
# trying
# 2020-04-13
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-13&src=typd
# trying
# 2020-04-14
# trying
# 2020-04-15
# trying
# 2020-04-16
# trying
# 2020-04-17
# trying
# 2020-04-18
# trying
# 2020-04-19
# trying
# 2020-04-20
# trying
# 2020-04-21
# trying
# 2020-04-22
# trying
# 2020-04-23
# trying
# 2020-04-24
# trying
# 2020-04-25
# trying
# 2020-04-26
# trying
# 2020-04-27
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-04-27&src=typd
# trying
# 2020-04-28
# trying
# 2020-04-29
# trying
# 2020-04-30
# trying
# 2020-05-01
# trying
# 2020-05-02
# trying
# 2020-05-03
# trying
# 2020-05-04
# trying
# 2020-05-05
# trying
# 2020-05-06
# trying
# 2020-05-07
# trying
# 2020-05-08
# trying
# 2020-05-09
# trying
# 2020-05-10
# trying
# 2020-05-11
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2240.658557%2C%20-73.837929%22%20within%3A40km%20until%3A2020-05-11&src=typd
# trying
# 2020-05-12
# trying
# 2020-05-13
# trying
# 2020-05-14
# trying
# 2020-05-15
# trying
# 2020-05-16
# trying
# 2020-05-17
# trying
# 2020-05-18
# trying
# 2020-05-19
# trying
# 2020-05-20
# trying
# 2020-05-21
# trying
# 2020-05-22
# trying
# 2020-05-23
# trying
# 2020-05-24
# trying
# 2020-05-25
# trying
# 2020-05-26
# trying
# 2020-05-27
# trying
# 2020-05-28
# trying
# 2020-05-29
# trying
# 2020-05-30
# trying
# 2020-05-31
# trying
# 2020-06-01
# trying
# 2020-06-02
# trying
# CPU times: user 14min 15s, sys: 41.7 s, total: 14min 57s
# Wall time: 3h 14min 23s

# %%
len(tweet_dict)

# %%
# %%time
import GetOldTweets3 as got
import datetime
import pandas as pd
import urllib.request as urllib2
from urllib.error import HTTPError
import time
import pickle
import retrying
import random
import os
full=pd.read_csv("county_centers.csv")
center=pd.DataFrame()
center['counties']=full['County [2]']
center['long']=full['Longitude']
center['lat']=full['Latitude']
start_date = datetime.date(2019, 12, 31)

end_date = datetime.date(2020, 6,1)

delta = datetime.timedelta(days=1)
i=0
inf_count=0

@retrying.retry(wait_fixed=10000)       
def retry_got(tweetCriteria):
    #print("trying")
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    return tweets
    

while inf_count<=10000:
    os.chdir("100")
    files_no_ext = [".".join(f.split(".")[:-1]) for f in os.listdir() if os.path.isfile(f)]
    os.chdir("..")
    
    
    i=random.randint(0, len(center.counties))
    if str(i) in files_no_ext:
        print("duplicate")
        continue
  
        
        
    df_tweets=pd.DataFrame(columns={str(i)})
    tweet_dict = {}

            
    while start_date <= end_date:
        start_date += delta
        df_tweets=df_tweets.append(pd.Series(name=start_date))
  
    
        location=str(center.lat[i])+", "+str(center.long[i])
        location = location.replace("°", "")
        location = location.replace("+", "")
        location=location.replace("\u2013", "-") #en dash

        #print(str(start_date))
        tweetCriteria = got.manager.TweetCriteria().setQuerySearch('*')\
                                           .setNear(location)\
                                           .setUntil(str(start_date))\
                                           .setMaxTweets(100)\
                                           .setWithin("40km")
                                                                      

        tweets=retry_got(tweetCriteria)
    
  
        for tweet in tweets:
            tweet_dict.setdefault(start_date, []).append(tweet)
            
    print(i)
    pickle.dump( tweet_dict, open( '100/'+str(i)+'.p', "wb" ) )
    start_date = datetime.date(2019, 12, 31)

    end_date = datetime.date(2020, 6, 1)
    inf_count=inf_count+1
# Out:
# C:\Users\Nikla\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2244.898036%2C%20-89.757823%22%20within%3A40km%20until%3A2020-03-23&src=typd
# 3084
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
# An error occured during an HTTP request: HTTP Error 429: Too Many Requests
# Try to open in browser: https://twitter.com/search?q=%2A%20near%3A%2239.041805%2C%20-95.755664%22%20within%3A40km%20until%3A2020-03-11&src=typd
